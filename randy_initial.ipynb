# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
import numpy as np

#import explore 
import prepare  
import acquire  
import model as m
import explore

import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

# imports for modeling
from sklearn.model_selection import train_test_split


from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# imports for modeling
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, recall_score, plot_confusion_matrix
from sklearn.linear_model import LogisticRegression

# imports for visualization
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm # for colormap tools
import seaborn as sns
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import seaborn as sns
from mergedeep import merge

plt.rc('figure', figsize=(13, 7))
plt.rc('font', size=16)
plt.style.use('seaborn-darkgrid')

# %%
from prepare import basic_clean, tokenize, stem, lemmatize, remove_stopwords, remove_urls, remove_unicode_text

# %%
from prepare import prepare_nlp_data

# %%
from scipy import stats

# %%
#Acquire the URLS for the Repositories to explore

headers = acquire.headers
endpoint = "https://api.github.com/search/repositories"
query = "customer in:name"
sort = "stars"
per_page = 100
order = "desc"
page = 1

##Make the request
response = requests.get(f"{endpoint}?q={query}&sort={sort}&per_page={per_page}&order={order}&page={page}", headers=headers)
payload = response.json()
#payload['items']

# %%
page = 2

##Make the request
response = requests.get(f"{endpoint}?q={query}&sort={sort}&per_page={per_page}&order={order}&page={page}", headers=headers)
payload2 = response.json()
merge(payload, payload2)
payload['items']
# Out:
# [{'id': 178226060,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzgyMjYwNjA=',
#   'name': 'E-commerce-Customer-service-robot',
#   'full_name': 'gongdelu/E-commerce-Customer-service-robot',
#   'private': False,
#   'owner': {'login': 'gongdelu',
#    'id': 37997947,
#    'node_id': 'MDQ6VXNlcjM3OTk3OTQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37997947?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gongdelu',
#    'html_url': 'https://github.com/gongdelu',
#    'followers_url': 'https://api.github.com/users/gongdelu/followers',
#    'following_url': 'https://api.github.com/users/gongdelu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gongdelu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gongdelu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gongdelu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gongdelu/orgs',
#    'repos_url': 'https://api.github.com/users/gongdelu/repos',
#    'events_url': 'https://api.github.com/users/gongdelu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gongdelu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/gongdelu/E-commerce-Customer-service-robot',
#   'description': '电商多轮对话智能机器人',
#   'fork': False,
#   'url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot',
#   'forks_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/forks',
#   'keys_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/teams',
#   'hooks_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/hooks',
#   'issue_events_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/events',
#   'assignees_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/tags',
#   'blobs_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/languages',
#   'stargazers_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/stargazers',
#   'contributors_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/contributors',
#   'subscribers_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/subscribers',
#   'subscription_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/subscription',
#   'commits_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/merges',
#   'archive_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/downloads',
#   'issues_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/gongdelu/E-commerce-Customer-service-robot/deployments',
#   'created_at': '2019-03-28T14:58:33Z',
#   'updated_at': '2021-09-20T02:54:52Z',
#   'pushed_at': '2019-03-31T12:57:03Z',
#   'git_url': 'git://github.com/gongdelu/E-commerce-Customer-service-robot.git',
#   'ssh_url': 'git@github.com:gongdelu/E-commerce-Customer-service-robot.git',
#   'clone_url': 'https://github.com/gongdelu/E-commerce-Customer-service-robot.git',
#   'svn_url': 'https://github.com/gongdelu/E-commerce-Customer-service-robot',
#   'homepage': '',
#   'size': 753,
#   'stargazers_count': 22,
#   'watchers_count': 22,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 10,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': ['deep-learning',
#    'machine-learning',
#    'nlp',
#    'seq2seq-chatbot',
#    'tutorial'],
#   'visibility': 'public',
#   'forks': 10,
#   'open_issues': 0,
#   'watchers': 22,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 102730304,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMDI3MzAzMDQ=',
#   'name': 'fta-customerfacingapps',
#   'full_name': 'Azure/fta-customerfacingapps',
#   'private': False,
#   'owner': {'login': 'Azure',
#    'id': 6844498,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY4NDQ0OTg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6844498?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Azure',
#    'html_url': 'https://github.com/Azure',
#    'followers_url': 'https://api.github.com/users/Azure/followers',
#    'following_url': 'https://api.github.com/users/Azure/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Azure/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Azure/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Azure/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Azure/orgs',
#    'repos_url': 'https://api.github.com/users/Azure/repos',
#    'events_url': 'https://api.github.com/users/Azure/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Azure/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Azure/fta-customerfacingapps',
#   'description': 'Fast Track for Azure - Customer Facing Apps solution',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Azure/fta-customerfacingapps',
#   'forks_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/forks',
#   'keys_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/teams',
#   'hooks_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/events',
#   'assignees_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/tags',
#   'blobs_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/languages',
#   'stargazers_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/subscription',
#   'commits_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/merges',
#   'archive_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/downloads',
#   'issues_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Azure/fta-customerfacingapps/deployments',
#   'created_at': '2017-09-07T11:43:16Z',
#   'updated_at': '2021-09-06T19:18:44Z',
#   'pushed_at': '2020-06-11T05:00:25Z',
#   'git_url': 'git://github.com/Azure/fta-customerfacingapps.git',
#   'ssh_url': 'git@github.com:Azure/fta-customerfacingapps.git',
#   'clone_url': 'https://github.com/Azure/fta-customerfacingapps.git',
#   'svn_url': 'https://github.com/Azure/fta-customerfacingapps',
#   'homepage': None,
#   'size': 19474,
#   'stargazers_count': 21,
#   'watchers_count': 21,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 58,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 58,
#   'open_issues': 4,
#   'watchers': 21,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 115764384,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTU3NjQzODQ=',
#   'name': 'CustomerAuthentication-With-ASP.NET-MVC',
#   'full_name': 'ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC',
#   'private': False,
#   'owner': {'login': 'ELMAHDI-AR',
#    'id': 26146273,
#    'node_id': 'MDQ6VXNlcjI2MTQ2Mjcz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26146273?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ELMAHDI-AR',
#    'html_url': 'https://github.com/ELMAHDI-AR',
#    'followers_url': 'https://api.github.com/users/ELMAHDI-AR/followers',
#    'following_url': 'https://api.github.com/users/ELMAHDI-AR/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ELMAHDI-AR/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ELMAHDI-AR/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ELMAHDI-AR/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ELMAHDI-AR/orgs',
#    'repos_url': 'https://api.github.com/users/ELMAHDI-AR/repos',
#    'events_url': 'https://api.github.com/users/ELMAHDI-AR/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ELMAHDI-AR/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC',
#   'forks_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/forks',
#   'keys_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/teams',
#   'hooks_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/hooks',
#   'issue_events_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/events',
#   'assignees_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/tags',
#   'blobs_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/languages',
#   'stargazers_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/stargazers',
#   'contributors_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/contributors',
#   'subscribers_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/subscription',
#   'commits_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/merges',
#   'archive_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/downloads',
#   'issues_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC/deployments',
#   'created_at': '2017-12-30T00:52:13Z',
#   'updated_at': '2021-09-28T03:33:21Z',
#   'pushed_at': '2017-12-30T00:53:07Z',
#   'git_url': 'git://github.com/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC.git',
#   'ssh_url': 'git@github.com:ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC.git',
#   'clone_url': 'https://github.com/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC.git',
#   'svn_url': 'https://github.com/ELMAHDI-AR/CustomerAuthentication-With-ASP.NET-MVC',
#   'homepage': None,
#   'size': 26839,
#   'stargazers_count': 21,
#   'watchers_count': 21,
#   'language': 'PowerShell',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 28,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 28,
#   'open_issues': 1,
#   'watchers': 21,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 62996724,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2Mjk5NjcyNA==',
#   'name': 'Customer-Analytics',
#   'full_name': 'kpei/Customer-Analytics',
#   'private': False,
#   'owner': {'login': 'kpei',
#    'id': 5482978,
#    'node_id': 'MDQ6VXNlcjU0ODI5Nzg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5482978?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kpei',
#    'html_url': 'https://github.com/kpei',
#    'followers_url': 'https://api.github.com/users/kpei/followers',
#    'following_url': 'https://api.github.com/users/kpei/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kpei/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kpei/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kpei/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kpei/orgs',
#    'repos_url': 'https://api.github.com/users/kpei/repos',
#    'events_url': 'https://api.github.com/users/kpei/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kpei/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/kpei/Customer-Analytics',
#   'description': 'Customer Analytics & Financial Valuation for Zakka Canada. This is the associated iPython Notebook code.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/kpei/Customer-Analytics',
#   'forks_url': 'https://api.github.com/repos/kpei/Customer-Analytics/forks',
#   'keys_url': 'https://api.github.com/repos/kpei/Customer-Analytics/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/kpei/Customer-Analytics/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/kpei/Customer-Analytics/teams',
#   'hooks_url': 'https://api.github.com/repos/kpei/Customer-Analytics/hooks',
#   'issue_events_url': 'https://api.github.com/repos/kpei/Customer-Analytics/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/kpei/Customer-Analytics/events',
#   'assignees_url': 'https://api.github.com/repos/kpei/Customer-Analytics/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/kpei/Customer-Analytics/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/kpei/Customer-Analytics/tags',
#   'blobs_url': 'https://api.github.com/repos/kpei/Customer-Analytics/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/kpei/Customer-Analytics/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/kpei/Customer-Analytics/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/kpei/Customer-Analytics/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/kpei/Customer-Analytics/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/kpei/Customer-Analytics/languages',
#   'stargazers_url': 'https://api.github.com/repos/kpei/Customer-Analytics/stargazers',
#   'contributors_url': 'https://api.github.com/repos/kpei/Customer-Analytics/contributors',
#   'subscribers_url': 'https://api.github.com/repos/kpei/Customer-Analytics/subscribers',
#   'subscription_url': 'https://api.github.com/repos/kpei/Customer-Analytics/subscription',
#   'commits_url': 'https://api.github.com/repos/kpei/Customer-Analytics/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/kpei/Customer-Analytics/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/kpei/Customer-Analytics/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/kpei/Customer-Analytics/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/kpei/Customer-Analytics/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/kpei/Customer-Analytics/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/kpei/Customer-Analytics/merges',
#   'archive_url': 'https://api.github.com/repos/kpei/Customer-Analytics/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/kpei/Customer-Analytics/downloads',
#   'issues_url': 'https://api.github.com/repos/kpei/Customer-Analytics/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/kpei/Customer-Analytics/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/kpei/Customer-Analytics/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/kpei/Customer-Analytics/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/kpei/Customer-Analytics/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/kpei/Customer-Analytics/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/kpei/Customer-Analytics/deployments',
#   'created_at': '2016-07-10T12:04:54Z',
#   'updated_at': '2021-05-07T09:24:41Z',
#   'pushed_at': '2016-07-10T12:08:42Z',
#   'git_url': 'git://github.com/kpei/Customer-Analytics.git',
#   'ssh_url': 'git@github.com:kpei/Customer-Analytics.git',
#   'clone_url': 'https://github.com/kpei/Customer-Analytics.git',
#   'svn_url': 'https://github.com/kpei/Customer-Analytics',
#   'homepage': 'http://kpei.me/blog/?p=921',
#   'size': 204,
#   'stargazers_count': 21,
#   'watchers_count': 21,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 19,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 19,
#   'open_issues': 1,
#   'watchers': 21,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 139696059,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzk2OTYwNTk=',
#   'name': 'CustomerOrderCancellationPlugin',
#   'full_name': 'Sylius/CustomerOrderCancellationPlugin',
#   'private': False,
#   'owner': {'login': 'Sylius',
#    'id': 719423,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcxOTQyMw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/719423?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sylius',
#    'html_url': 'https://github.com/Sylius',
#    'followers_url': 'https://api.github.com/users/Sylius/followers',
#    'following_url': 'https://api.github.com/users/Sylius/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Sylius/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Sylius/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Sylius/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Sylius/orgs',
#    'repos_url': 'https://api.github.com/users/Sylius/repos',
#    'events_url': 'https://api.github.com/users/Sylius/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Sylius/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Sylius/CustomerOrderCancellationPlugin',
#   'description': 'Plugin that allows customers to cancel the placed order before it is processed.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin',
#   'forks_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/forks',
#   'keys_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/teams',
#   'hooks_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/events',
#   'assignees_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/tags',
#   'blobs_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/languages',
#   'stargazers_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/subscription',
#   'commits_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/merges',
#   'archive_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/downloads',
#   'issues_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Sylius/CustomerOrderCancellationPlugin/deployments',
#   'created_at': '2018-07-04T08:57:03Z',
#   'updated_at': '2021-10-12T07:40:40Z',
#   'pushed_at': '2021-10-12T07:35:06Z',
#   'git_url': 'git://github.com/Sylius/CustomerOrderCancellationPlugin.git',
#   'ssh_url': 'git@github.com:Sylius/CustomerOrderCancellationPlugin.git',
#   'clone_url': 'https://github.com/Sylius/CustomerOrderCancellationPlugin.git',
#   'svn_url': 'https://github.com/Sylius/CustomerOrderCancellationPlugin',
#   'homepage': None,
#   'size': 241,
#   'stargazers_count': 21,
#   'watchers_count': 21,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 7,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 5,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': ['php', 'sylius', 'sylius-plugin'],
#   'visibility': 'public',
#   'forks': 7,
#   'open_issues': 5,
#   'watchers': 21,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 164205742,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNjQyMDU3NDI=',
#   'name': 'rfm-customer-segmentation',
#   'full_name': 'optiflow/rfm-customer-segmentation',
#   'private': False,
#   'owner': {'login': 'optiflow',
#    'id': 7366789,
#    'node_id': 'MDQ6VXNlcjczNjY3ODk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7366789?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/optiflow',
#    'html_url': 'https://github.com/optiflow',
#    'followers_url': 'https://api.github.com/users/optiflow/followers',
#    'following_url': 'https://api.github.com/users/optiflow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/optiflow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/optiflow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/optiflow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/optiflow/orgs',
#    'repos_url': 'https://api.github.com/users/optiflow/repos',
#    'events_url': 'https://api.github.com/users/optiflow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/optiflow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/optiflow/rfm-customer-segmentation',
#   'description': 'Unsupervised Clustering on Online Retail Dataset ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation',
#   'forks_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/forks',
#   'keys_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/teams',
#   'hooks_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/hooks',
#   'issue_events_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/events',
#   'assignees_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/tags',
#   'blobs_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/languages',
#   'stargazers_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/stargazers',
#   'contributors_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/contributors',
#   'subscribers_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/subscribers',
#   'subscription_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/subscription',
#   'commits_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/merges',
#   'archive_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/downloads',
#   'issues_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/optiflow/rfm-customer-segmentation/deployments',
#   'created_at': '2019-01-05T10:44:09Z',
#   'updated_at': '2021-09-20T00:38:39Z',
#   'pushed_at': '2019-03-24T05:43:55Z',
#   'git_url': 'git://github.com/optiflow/rfm-customer-segmentation.git',
#   'ssh_url': 'git@github.com:optiflow/rfm-customer-segmentation.git',
#   'clone_url': 'https://github.com/optiflow/rfm-customer-segmentation.git',
#   'svn_url': 'https://github.com/optiflow/rfm-customer-segmentation',
#   'homepage': 'https://towardsdatascience.com/the-most-important-data-science-tool-for-market-and-customer-segmentation-c9709ca0b64a',
#   'size': 3066,
#   'stargazers_count': 21,
#   'watchers_count': 21,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 9,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 9,
#   'open_issues': 0,
#   'watchers': 21,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 62323384,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MjMyMzM4NA==',
#   'name': 'social-customer-care',
#   'full_name': 'watson-developer-cloud/social-customer-care',
#   'private': False,
#   'owner': {'login': 'watson-developer-cloud',
#    'id': 10017763,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEwMDE3NzYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10017763?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/watson-developer-cloud',
#    'html_url': 'https://github.com/watson-developer-cloud',
#    'followers_url': 'https://api.github.com/users/watson-developer-cloud/followers',
#    'following_url': 'https://api.github.com/users/watson-developer-cloud/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/watson-developer-cloud/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/watson-developer-cloud/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/watson-developer-cloud/subscriptions',
#    'organizations_url': 'https://api.github.com/users/watson-developer-cloud/orgs',
#    'repos_url': 'https://api.github.com/users/watson-developer-cloud/repos',
#    'events_url': 'https://api.github.com/users/watson-developer-cloud/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/watson-developer-cloud/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/watson-developer-cloud/social-customer-care',
#   'description': 'DEPRECATED: this repo is no longer actively maintained',
#   'fork': False,
#   'url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care',
#   'forks_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/forks',
#   'keys_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/teams',
#   'hooks_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/hooks',
#   'issue_events_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/events',
#   'assignees_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/tags',
#   'blobs_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/languages',
#   'stargazers_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/stargazers',
#   'contributors_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/contributors',
#   'subscribers_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/subscribers',
#   'subscription_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/subscription',
#   'commits_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/merges',
#   'archive_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/downloads',
#   'issues_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/watson-developer-cloud/social-customer-care/deployments',
#   'created_at': '2016-06-30T15:46:11Z',
#   'updated_at': '2019-07-15T13:24:25Z',
#   'pushed_at': '2019-07-15T13:21:58Z',
#   'git_url': 'git://github.com/watson-developer-cloud/social-customer-care.git',
#   'ssh_url': 'git@github.com:watson-developer-cloud/social-customer-care.git',
#   'clone_url': 'https://github.com/watson-developer-cloud/social-customer-care.git',
#   'svn_url': 'https://github.com/watson-developer-cloud/social-customer-care',
#   'homepage': '',
#   'size': 603,
#   'stargazers_count': 20,
#   'watchers_count': 20,
#   'language': 'CSS',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 62,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 62,
#   'open_issues': 0,
#   'watchers': 20,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 129873405,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMjk4NzM0MDU=',
#   'name': 'CustomerReorderPlugin',
#   'full_name': 'Sylius/CustomerReorderPlugin',
#   'private': False,
#   'owner': {'login': 'Sylius',
#    'id': 719423,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcxOTQyMw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/719423?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sylius',
#    'html_url': 'https://github.com/Sylius',
#    'followers_url': 'https://api.github.com/users/Sylius/followers',
#    'following_url': 'https://api.github.com/users/Sylius/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Sylius/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Sylius/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Sylius/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Sylius/orgs',
#    'repos_url': 'https://api.github.com/users/Sylius/repos',
#    'events_url': 'https://api.github.com/users/Sylius/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Sylius/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/Sylius/CustomerReorderPlugin',
#   'description': 'Plugin that allows customers to reorder previously placed order.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin',
#   'forks_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/forks',
#   'keys_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/teams',
#   'hooks_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/events',
#   'assignees_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/tags',
#   'blobs_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/languages',
#   'stargazers_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/subscription',
#   'commits_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Sylius/CustomerReorderPlugin/comments{/number}',
# ...
#   'languages_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/languages',
#   'stargazers_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/subscription',
#   'commits_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/merges',
#   'archive_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/downloads',
#   'issues_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Fizzzzer/Android_Fizzer_CustomerCamera/deployments',
#   'created_at': '2016-12-30T01:59:59Z',
#   'updated_at': '2020-02-21T14:25:59Z',
#   'pushed_at': '2020-02-21T14:25:56Z',
#   'git_url': 'git://github.com/Fizzzzer/Android_Fizzer_CustomerCamera.git',
#   'ssh_url': 'git@github.com:Fizzzzer/Android_Fizzer_CustomerCamera.git',
#   'clone_url': 'https://github.com/Fizzzzer/Android_Fizzer_CustomerCamera.git',
#   'svn_url': 'https://github.com/Fizzzzer/Android_Fizzer_CustomerCamera',
#   'homepage': '',
#   'size': 351,
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 11,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 364852428,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjQ4NTI0Mjg=',
#   'name': 'CustomerManagementSystem',
#   'full_name': 'smtdeveloper/CustomerManagementSystem',
#   'private': False,
#   'owner': {'login': 'smtdeveloper',
#    'id': 74311713,
#    'node_id': 'MDQ6VXNlcjc0MzExNzEz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74311713?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smtdeveloper',
#    'html_url': 'https://github.com/smtdeveloper',
#    'followers_url': 'https://api.github.com/users/smtdeveloper/followers',
#    'following_url': 'https://api.github.com/users/smtdeveloper/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/smtdeveloper/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/smtdeveloper/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/smtdeveloper/subscriptions',
#    'organizations_url': 'https://api.github.com/users/smtdeveloper/orgs',
#    'repos_url': 'https://api.github.com/users/smtdeveloper/repos',
#    'events_url': 'https://api.github.com/users/smtdeveloper/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/smtdeveloper/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/smtdeveloper/CustomerManagementSystem',
#   'description': 'Mernis ile TC Doğrulama - Müşteri Yönetim Sistemi ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem',
#   'forks_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/forks',
#   'keys_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/teams',
#   'hooks_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/hooks',
#   'issue_events_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/events',
#   'assignees_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/tags',
#   'blobs_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/languages',
#   'stargazers_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/stargazers',
#   'contributors_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/contributors',
#   'subscribers_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/subscribers',
#   'subscription_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/subscription',
#   'commits_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/merges',
#   'archive_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/downloads',
#   'issues_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/smtdeveloper/CustomerManagementSystem/deployments',
#   'created_at': '2021-05-06T09:16:16Z',
#   'updated_at': '2021-08-21T14:08:16Z',
#   'pushed_at': '2021-08-18T14:08:57Z',
#   'git_url': 'git://github.com/smtdeveloper/CustomerManagementSystem.git',
#   'ssh_url': 'git@github.com:smtdeveloper/CustomerManagementSystem.git',
#   'clone_url': 'https://github.com/smtdeveloper/CustomerManagementSystem.git',
#   'svn_url': 'https://github.com/smtdeveloper/CustomerManagementSystem',
#   'homepage': '',
#   'size': 24,
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 11,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 9009395,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk5MDA5Mzk1',
#   'name': 'magento-GetCustomerFeedback',
#   'full_name': 'gaiterjones/magento-GetCustomerFeedback',
#   'private': False,
#   'owner': {'login': 'gaiterjones',
#    'id': 3909886,
#    'node_id': 'MDQ6VXNlcjM5MDk4ODY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3909886?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gaiterjones',
#    'html_url': 'https://github.com/gaiterjones',
#    'followers_url': 'https://api.github.com/users/gaiterjones/followers',
#    'following_url': 'https://api.github.com/users/gaiterjones/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gaiterjones/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gaiterjones/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gaiterjones/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gaiterjones/orgs',
#    'repos_url': 'https://api.github.com/users/gaiterjones/repos',
#    'events_url': 'https://api.github.com/users/gaiterjones/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gaiterjones/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/gaiterjones/magento-GetCustomerFeedback',
#   'description': 'Customer feedback module for Magento',
#   'fork': False,
#   'url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback',
#   'forks_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/forks',
#   'keys_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/teams',
#   'hooks_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/hooks',
#   'issue_events_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/events',
#   'assignees_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/tags',
#   'blobs_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/languages',
#   'stargazers_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/stargazers',
#   'contributors_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/contributors',
#   'subscribers_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/subscribers',
#   'subscription_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/subscription',
#   'commits_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/merges',
#   'archive_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/downloads',
#   'issues_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/gaiterjones/magento-GetCustomerFeedback/deployments',
#   'created_at': '2013-03-25T15:32:27Z',
#   'updated_at': '2018-04-26T10:23:42Z',
#   'pushed_at': '2017-06-02T15:43:38Z',
#   'git_url': 'git://github.com/gaiterjones/magento-GetCustomerFeedback.git',
#   'ssh_url': 'git@github.com:gaiterjones/magento-GetCustomerFeedback.git',
#   'clone_url': 'https://github.com/gaiterjones/magento-GetCustomerFeedback.git',
#   'svn_url': 'https://github.com/gaiterjones/magento-GetCustomerFeedback',
#   'homepage': 'blog.gaiterjones.com',
#   'size': 53,
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 11,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0}]

# %%
page = 3

##Make the request
response = requests.get(f"{endpoint}?q={query}&sort={sort}&per_page={per_page}&order={order}&page={page}", headers=headers)
payload2 = response.json()
merge(payload, payload2)
payload['items']
# Out:
# [{'id': 118996371,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTg5OTYzNzE=',
#   'name': 'CustomerChurn',
#   'full_name': 'smit5490/CustomerChurn',
#   'private': False,
#   'owner': {'login': 'smit5490',
#    'id': 13723626,
#    'node_id': 'MDQ6VXNlcjEzNzIzNjI2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13723626?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smit5490',
#    'html_url': 'https://github.com/smit5490',
#    'followers_url': 'https://api.github.com/users/smit5490/followers',
#    'following_url': 'https://api.github.com/users/smit5490/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/smit5490/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/smit5490/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/smit5490/subscriptions',
#    'organizations_url': 'https://api.github.com/users/smit5490/orgs',
#    'repos_url': 'https://api.github.com/users/smit5490/repos',
#    'events_url': 'https://api.github.com/users/smit5490/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/smit5490/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/smit5490/CustomerChurn',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/smit5490/CustomerChurn',
#   'forks_url': 'https://api.github.com/repos/smit5490/CustomerChurn/forks',
#   'keys_url': 'https://api.github.com/repos/smit5490/CustomerChurn/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/smit5490/CustomerChurn/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/smit5490/CustomerChurn/teams',
#   'hooks_url': 'https://api.github.com/repos/smit5490/CustomerChurn/hooks',
#   'issue_events_url': 'https://api.github.com/repos/smit5490/CustomerChurn/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/smit5490/CustomerChurn/events',
#   'assignees_url': 'https://api.github.com/repos/smit5490/CustomerChurn/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/smit5490/CustomerChurn/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/smit5490/CustomerChurn/tags',
#   'blobs_url': 'https://api.github.com/repos/smit5490/CustomerChurn/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/smit5490/CustomerChurn/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/smit5490/CustomerChurn/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/smit5490/CustomerChurn/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/smit5490/CustomerChurn/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/smit5490/CustomerChurn/languages',
#   'stargazers_url': 'https://api.github.com/repos/smit5490/CustomerChurn/stargazers',
#   'contributors_url': 'https://api.github.com/repos/smit5490/CustomerChurn/contributors',
#   'subscribers_url': 'https://api.github.com/repos/smit5490/CustomerChurn/subscribers',
#   'subscription_url': 'https://api.github.com/repos/smit5490/CustomerChurn/subscription',
#   'commits_url': 'https://api.github.com/repos/smit5490/CustomerChurn/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/smit5490/CustomerChurn/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/smit5490/CustomerChurn/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/smit5490/CustomerChurn/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/smit5490/CustomerChurn/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/smit5490/CustomerChurn/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/smit5490/CustomerChurn/merges',
#   'archive_url': 'https://api.github.com/repos/smit5490/CustomerChurn/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/smit5490/CustomerChurn/downloads',
#   'issues_url': 'https://api.github.com/repos/smit5490/CustomerChurn/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/smit5490/CustomerChurn/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/smit5490/CustomerChurn/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/smit5490/CustomerChurn/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/smit5490/CustomerChurn/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/smit5490/CustomerChurn/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/smit5490/CustomerChurn/deployments',
#   'created_at': '2018-01-26T02:44:37Z',
#   'updated_at': '2020-09-04T02:43:12Z',
#   'pushed_at': '2021-08-23T20:51:17Z',
#   'git_url': 'git://github.com/smit5490/CustomerChurn.git',
#   'ssh_url': 'git@github.com:smit5490/CustomerChurn.git',
#   'clone_url': 'https://github.com/smit5490/CustomerChurn.git',
#   'svn_url': 'https://github.com/smit5490/CustomerChurn',
#   'homepage': None,
#   'size': 1812,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 8,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 8,
#   'open_issues': 4,
#   'watchers': 10,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 58745539,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1ODc0NTUzOQ==',
#   'name': 'vc-module-customer',
#   'full_name': 'VirtoCommerce/vc-module-customer',
#   'private': False,
#   'owner': {'login': 'VirtoCommerce',
#    'id': 5762443,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU3NjI0NDM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5762443?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VirtoCommerce',
#    'html_url': 'https://github.com/VirtoCommerce',
#    'followers_url': 'https://api.github.com/users/VirtoCommerce/followers',
#    'following_url': 'https://api.github.com/users/VirtoCommerce/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/VirtoCommerce/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/VirtoCommerce/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/VirtoCommerce/subscriptions',
#    'organizations_url': 'https://api.github.com/users/VirtoCommerce/orgs',
#    'repos_url': 'https://api.github.com/users/VirtoCommerce/repos',
#    'events_url': 'https://api.github.com/users/VirtoCommerce/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/VirtoCommerce/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/VirtoCommerce/vc-module-customer',
#   'description': ' Contacts management module',
#   'fork': False,
#   'url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer',
#   'forks_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/forks',
#   'keys_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/teams',
#   'hooks_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/hooks',
#   'issue_events_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/events',
#   'assignees_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/tags',
#   'blobs_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/languages',
#   'stargazers_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/stargazers',
#   'contributors_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/contributors',
#   'subscribers_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/subscribers',
#   'subscription_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/subscription',
#   'commits_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/merges',
#   'archive_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/downloads',
#   'issues_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/VirtoCommerce/vc-module-customer/deployments',
#   'created_at': '2016-05-13T14:06:52Z',
#   'updated_at': '2021-10-27T08:27:01Z',
#   'pushed_at': '2021-10-27T08:30:31Z',
#   'git_url': 'git://github.com/VirtoCommerce/vc-module-customer.git',
#   'ssh_url': 'git@github.com:VirtoCommerce/vc-module-customer.git',
#   'clone_url': 'https://github.com/VirtoCommerce/vc-module-customer.git',
#   'svn_url': 'https://github.com/VirtoCommerce/vc-module-customer',
#   'homepage': '',
#   'size': 3421,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 21,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 21,
#   'open_issues': 14,
#   'watchers': 10,
#   'default_branch': 'dev',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 62332503,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MjMzMjUwMw==',
#   'name': 'customer_portal',
#   'full_name': 'SonarSoftware/customer_portal',
#   'private': False,
#   'owner': {'login': 'SonarSoftware',
#    'id': 12124408,
#    'node_id': 'MDQ6VXNlcjEyMTI0NDA4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12124408?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SonarSoftware',
#    'html_url': 'https://github.com/SonarSoftware',
#    'followers_url': 'https://api.github.com/users/SonarSoftware/followers',
#    'following_url': 'https://api.github.com/users/SonarSoftware/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SonarSoftware/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SonarSoftware/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SonarSoftware/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SonarSoftware/orgs',
#    'repos_url': 'https://api.github.com/users/SonarSoftware/repos',
#    'events_url': 'https://api.github.com/users/SonarSoftware/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SonarSoftware/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/SonarSoftware/customer_portal',
#   'description': 'A customer portal for Sonar.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/SonarSoftware/customer_portal',
#   'forks_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/forks',
#   'keys_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/teams',
#   'hooks_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/hooks',
#   'issue_events_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/events',
#   'assignees_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/tags',
#   'blobs_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/languages',
#   'stargazers_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/stargazers',
#   'contributors_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/contributors',
#   'subscribers_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/subscribers',
#   'subscription_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/subscription',
#   'commits_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/merges',
#   'archive_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/downloads',
#   'issues_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/SonarSoftware/customer_portal/deployments',
#   'created_at': '2016-06-30T18:10:03Z',
#   'updated_at': '2021-01-15T09:07:13Z',
#   'pushed_at': '2019-11-02T13:59:41Z',
#   'git_url': 'git://github.com/SonarSoftware/customer_portal.git',
#   'ssh_url': 'git@github.com:SonarSoftware/customer_portal.git',
#   'clone_url': 'https://github.com/SonarSoftware/customer_portal.git',
#   'svn_url': 'https://github.com/SonarSoftware/customer_portal',
#   'homepage': None,
#   'size': 13647,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'forks_count': 15,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 15,
#   'open_issues': 1,
#   'watchers': 10,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 85580569,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk4NTU4MDU2OQ==',
#   'name': 'customer-portal',
#   'full_name': 'oroinc/customer-portal',
#   'private': False,
#   'owner': {'login': 'oroinc',
#    'id': 4165718,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQxNjU3MTg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4165718?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/oroinc',
#    'html_url': 'https://github.com/oroinc',
#    'followers_url': 'https://api.github.com/users/oroinc/followers',
#    'following_url': 'https://api.github.com/users/oroinc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/oroinc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/oroinc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/oroinc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/oroinc/orgs',
#    'repos_url': 'https://api.github.com/users/oroinc/repos',
#    'events_url': 'https://api.github.com/users/oroinc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/oroinc/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/oroinc/customer-portal',
#   'description': 'OroCommerce package with customer portal and non authenticated visitor website base features.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/oroinc/customer-portal',
#   'forks_url': 'https://api.github.com/repos/oroinc/customer-portal/forks',
#   'keys_url': 'https://api.github.com/repos/oroinc/customer-portal/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/oroinc/customer-portal/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/oroinc/customer-portal/teams',
#   'hooks_url': 'https://api.github.com/repos/oroinc/customer-portal/hooks',
#   'issue_events_url': 'https://api.github.com/repos/oroinc/customer-portal/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/oroinc/customer-portal/events',
#   'assignees_url': 'https://api.github.com/repos/oroinc/customer-portal/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/oroinc/customer-portal/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/oroinc/customer-portal/tags',
#   'blobs_url': 'https://api.github.com/repos/oroinc/customer-portal/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/oroinc/customer-portal/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/oroinc/customer-portal/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/oroinc/customer-portal/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/oroinc/customer-portal/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/oroinc/customer-portal/languages',
#   'stargazers_url': 'https://api.github.com/repos/oroinc/customer-portal/stargazers',
#   'contributors_url': 'https://api.github.com/repos/oroinc/customer-portal/contributors',
#   'subscribers_url': 'https://api.github.com/repos/oroinc/customer-portal/subscribers',
#   'subscription_url': 'https://api.github.com/repos/oroinc/customer-portal/subscription',
#   'commits_url': 'https://api.github.com/repos/oroinc/customer-portal/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/oroinc/customer-portal/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/oroinc/customer-portal/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/oroinc/customer-portal/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/oroinc/customer-portal/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/oroinc/customer-portal/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/oroinc/customer-portal/merges',
#   'archive_url': 'https://api.github.com/repos/oroinc/customer-portal/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/oroinc/customer-portal/downloads',
#   'issues_url': 'https://api.github.com/repos/oroinc/customer-portal/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/oroinc/customer-portal/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/oroinc/customer-portal/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/oroinc/customer-portal/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/oroinc/customer-portal/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/oroinc/customer-portal/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/oroinc/customer-portal/deployments',
#   'created_at': '2017-03-20T13:34:26Z',
#   'updated_at': '2021-10-29T20:22:36Z',
#   'pushed_at': '2021-10-29T20:22:31Z',
#   'git_url': 'git://github.com/oroinc/customer-portal.git',
#   'ssh_url': 'git@github.com:oroinc/customer-portal.git',
#   'clone_url': 'https://github.com/oroinc/customer-portal.git',
#   'svn_url': 'https://github.com/oroinc/customer-portal',
#   'homepage': '',
#   'size': 11641,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 15,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 5,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 15,
#   'open_issues': 5,
#   'watchers': 10,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 47967191,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0Nzk2NzE5MQ==',
#   'name': 'customer-scripts',
#   'full_name': 'microsoft/customer-scripts',
#   'private': False,
#   'owner': {'login': 'microsoft',
#    'id': 6154722,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/microsoft',
#    'html_url': 'https://github.com/microsoft',
#    'followers_url': 'https://api.github.com/users/microsoft/followers',
#    'following_url': 'https://api.github.com/users/microsoft/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions',
#    'organizations_url': 'https://api.github.com/users/microsoft/orgs',
#    'repos_url': 'https://api.github.com/users/microsoft/repos',
#    'events_url': 'https://api.github.com/users/microsoft/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/microsoft/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/microsoft/customer-scripts',
#   'description': 'Repository of scripts provided frequently to our customers',
#   'fork': False,
#   'url': 'https://api.github.com/repos/microsoft/customer-scripts',
#   'forks_url': 'https://api.github.com/repos/microsoft/customer-scripts/forks',
#   'keys_url': 'https://api.github.com/repos/microsoft/customer-scripts/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/microsoft/customer-scripts/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/microsoft/customer-scripts/teams',
#   'hooks_url': 'https://api.github.com/repos/microsoft/customer-scripts/hooks',
#   'issue_events_url': 'https://api.github.com/repos/microsoft/customer-scripts/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/microsoft/customer-scripts/events',
#   'assignees_url': 'https://api.github.com/repos/microsoft/customer-scripts/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/microsoft/customer-scripts/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/microsoft/customer-scripts/tags',
#   'blobs_url': 'https://api.github.com/repos/microsoft/customer-scripts/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/microsoft/customer-scripts/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/microsoft/customer-scripts/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/microsoft/customer-scripts/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/microsoft/customer-scripts/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/microsoft/customer-scripts/languages',
#   'stargazers_url': 'https://api.github.com/repos/microsoft/customer-scripts/stargazers',
#   'contributors_url': 'https://api.github.com/repos/microsoft/customer-scripts/contributors',
#   'subscribers_url': 'https://api.github.com/repos/microsoft/customer-scripts/subscribers',
#   'subscription_url': 'https://api.github.com/repos/microsoft/customer-scripts/subscription',
#   'commits_url': 'https://api.github.com/repos/microsoft/customer-scripts/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/microsoft/customer-scripts/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/microsoft/customer-scripts/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/microsoft/customer-scripts/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/microsoft/customer-scripts/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/microsoft/customer-scripts/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/microsoft/customer-scripts/merges',
#   'archive_url': 'https://api.github.com/repos/microsoft/customer-scripts/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/microsoft/customer-scripts/downloads',
#   'issues_url': 'https://api.github.com/repos/microsoft/customer-scripts/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/microsoft/customer-scripts/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/microsoft/customer-scripts/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/microsoft/customer-scripts/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/microsoft/customer-scripts/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/microsoft/customer-scripts/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/microsoft/customer-scripts/deployments',
#   'created_at': '2015-12-14T10:13:44Z',
#   'updated_at': '2021-04-20T15:59:32Z',
#   'pushed_at': '2017-03-28T21:28:54Z',
#   'git_url': 'git://github.com/microsoft/customer-scripts.git',
#   'ssh_url': 'git@github.com:microsoft/customer-scripts.git',
#   'clone_url': 'https://github.com/microsoft/customer-scripts.git',
#   'svn_url': 'https://github.com/microsoft/customer-scripts',
#   'homepage': None,
#   'size': 6,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'PowerShell',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 13,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 13,
#   'open_issues': 1,
#   'watchers': 10,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 117395661,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTczOTU2NjE=',
#   'name': 'example-customers-app',
#   'full_name': 'correooke/example-customers-app',
#   'private': False,
#   'owner': {'login': 'correooke',
#    'id': 8355916,
#    'node_id': 'MDQ6VXNlcjgzNTU5MTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8355916?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/correooke',
#    'html_url': 'https://github.com/correooke',
#    'followers_url': 'https://api.github.com/users/correooke/followers',
#    'following_url': 'https://api.github.com/users/correooke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/correooke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/correooke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/correooke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/correooke/orgs',
#    'repos_url': 'https://api.github.com/users/correooke/repos',
#    'events_url': 'https://api.github.com/users/correooke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/correooke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/correooke/example-customers-app',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/correooke/example-customers-app',
#   'forks_url': 'https://api.github.com/repos/correooke/example-customers-app/forks',
#   'keys_url': 'https://api.github.com/repos/correooke/example-customers-app/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/correooke/example-customers-app/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/correooke/example-customers-app/teams',
#   'hooks_url': 'https://api.github.com/repos/correooke/example-customers-app/hooks',
#   'issue_events_url': 'https://api.github.com/repos/correooke/example-customers-app/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/correooke/example-customers-app/events',
#   'assignees_url': 'https://api.github.com/repos/correooke/example-customers-app/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/correooke/example-customers-app/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/correooke/example-customers-app/tags',
#   'blobs_url': 'https://api.github.com/repos/correooke/example-customers-app/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/correooke/example-customers-app/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/correooke/example-customers-app/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/correooke/example-customers-app/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/correooke/example-customers-app/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/correooke/example-customers-app/languages',
#   'stargazers_url': 'https://api.github.com/repos/correooke/example-customers-app/stargazers',
#   'contributors_url': 'https://api.github.com/repos/correooke/example-customers-app/contributors',
#   'subscribers_url': 'https://api.github.com/repos/correooke/example-customers-app/subscribers',
#   'subscription_url': 'https://api.github.com/repos/correooke/example-customers-app/subscription',
#   'commits_url': 'https://api.github.com/repos/correooke/example-customers-app/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/correooke/example-customers-app/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/correooke/example-customers-app/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/correooke/example-customers-app/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/correooke/example-customers-app/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/correooke/example-customers-app/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/correooke/example-customers-app/merges',
#   'archive_url': 'https://api.github.com/repos/correooke/example-customers-app/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/correooke/example-customers-app/downloads',
#   'issues_url': 'https://api.github.com/repos/correooke/example-customers-app/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/correooke/example-customers-app/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/correooke/example-customers-app/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/correooke/example-customers-app/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/correooke/example-customers-app/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/correooke/example-customers-app/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/correooke/example-customers-app/deployments',
#   'created_at': '2018-01-14T02:32:50Z',
#   'updated_at': '2021-07-03T22:29:25Z',
#   'pushed_at': '2020-03-02T19:36:28Z',
#   'git_url': 'git://github.com/correooke/example-customers-app.git',
#   'ssh_url': 'git@github.com:correooke/example-customers-app.git',
#   'clone_url': 'https://github.com/correooke/example-customers-app.git',
#   'svn_url': 'https://github.com/correooke/example-customers-app',
#   'homepage': None,
#   'size': 200,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 18,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 18,
#   'open_issues': 1,
#   'watchers': 10,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 74846002,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3NDg0NjAwMg==',
#   'name': 'mlnd-customer-segments',
#   'full_name': 'darkdreamingdan/mlnd-customer-segments',
#   'private': False,
#   'owner': {'login': 'darkdreamingdan',
#    'id': 124611,
#    'node_id': 'MDQ6VXNlcjEyNDYxMQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/124611?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/darkdreamingdan',
#    'html_url': 'https://github.com/darkdreamingdan',
#    'followers_url': 'https://api.github.com/users/darkdreamingdan/followers',
#    'following_url': 'https://api.github.com/users/darkdreamingdan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/darkdreamingdan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/darkdreamingdan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/darkdreamingdan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/darkdreamingdan/orgs',
#    'repos_url': 'https://api.github.com/users/darkdreamingdan/repos',
#    'events_url': 'https://api.github.com/users/darkdreamingdan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/darkdreamingdan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/darkdreamingdan/mlnd-customer-segments',
#   'description': 'udacity machine learning nanodegree Project 3: Customer Segments',
#   'fork': False,
#   'url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments',
#   'forks_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/forks',
#   'keys_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/teams',
#   'hooks_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/hooks',
#   'issue_events_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/events',
#   'assignees_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/tags',
#   'blobs_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/languages',
#   'stargazers_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/stargazers',
#   'contributors_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/contributors',
#   'subscribers_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/subscribers',
#   'subscription_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/subscription',
#   'commits_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/merges',
#   'archive_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/downloads',
#   'issues_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/darkdreamingdan/mlnd-customer-segments/deployments',
#   'created_at': '2016-11-26T19:26:57Z',
#   'updated_at': '2019-06-29T05:59:48Z',
#   'pushed_at': '2016-12-11T14:15:05Z',
#   'git_url': 'git://github.com/darkdreamingdan/mlnd-customer-segments.git',
#   'ssh_url': 'git@github.com:darkdreamingdan/mlnd-customer-segments.git',
#   'clone_url': 'https://github.com/darkdreamingdan/mlnd-customer-segments.git',
#   'svn_url': 'https://github.com/darkdreamingdan/mlnd-customer-segments',
#   'homepage': None,
#   'size': 2296,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'HTML',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': False,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 14,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 14,
#   'open_issues': 0,
#   'watchers': 10,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 159208572,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNTkyMDg1NzI=',
#   'name': 'CustomerSync-Refactoring-Kata',
#   'full_name': 'emilybache/CustomerSync-Refactoring-Kata',
#   'private': False,
#   'owner': {'login': 'emilybache',
#    'id': 48844,
#    'node_id': 'MDQ6VXNlcjQ4ODQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48844?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/emilybache',
#    'html_url': 'https://github.com/emilybache',
#    'followers_url': 'https://api.github.com/users/emilybache/followers',
#    'following_url': 'https://api.github.com/users/emilybache/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/emilybache/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/emilybache/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/emilybache/subscriptions',
#    'organizations_url': 'https://api.github.com/users/emilybache/orgs',
#    'repos_url': 'https://api.github.com/users/emilybache/repos',
#    'events_url': 'https://api.github.com/users/emilybache/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/emilybache/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/emilybache/CustomerSync-Refactoring-Kata',
#   'description': 'Refactoring exercise where data layer and business layer are not clearly separated',
#   'fork': False,
#   'url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata',
#   'forks_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/forks',
#   'keys_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/teams',
#   'hooks_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/hooks',
#   'issue_events_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/events',
#   'assignees_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/tags',
#   'blobs_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/languages',
#   'stargazers_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/stargazers',
#   'contributors_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/contributors',
#   'subscribers_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/subscribers',
#   'subscription_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/subscription',
#   'commits_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/merges',
#   'archive_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/downloads',
#   'issues_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/emilybache/CustomerSync-Refactoring-Kata/deployments',
#   'created_at': '2018-11-26T17:37:57Z',
#   'updated_at': '2021-09-28T14:44:53Z',
#   'pushed_at': '2021-09-27T11:48:26Z',
#   'git_url': 'git://github.com/emilybache/CustomerSync-Refactoring-Kata.git',
#   'ssh_url': 'git@github.com:emilybache/CustomerSync-Refactoring-Kata.git',
#   'clone_url': 'https://github.com/emilybache/CustomerSync-Refactoring-Kata.git',
#   'svn_url': 'https://github.com/emilybache/CustomerSync-Refactoring-Kata',
#   'homepage': None,
#   'size': 70,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 6,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
# ...
#   'compare_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/merges',
#   'archive_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/downloads',
#   'issues_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction/deployments',
#   'created_at': '2018-09-19T06:02:11Z',
#   'updated_at': '2021-07-14T14:02:24Z',
#   'pushed_at': '2020-10-20T21:00:32Z',
#   'git_url': 'git://github.com/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction.git',
#   'ssh_url': 'git@github.com:Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction.git',
#   'clone_url': 'https://github.com/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction.git',
#   'svn_url': 'https://github.com/Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction',
#   'homepage': '',
#   'size': 535,
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 7,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 113375100,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTMzNzUxMDA=',
#   'name': 'woocommerce-customer-source',
#   'full_name': 'devinsays/woocommerce-customer-source',
#   'private': False,
#   'owner': {'login': 'devinsays',
#    'id': 431879,
#    'node_id': 'MDQ6VXNlcjQzMTg3OQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/431879?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/devinsays',
#    'html_url': 'https://github.com/devinsays',
#    'followers_url': 'https://api.github.com/users/devinsays/followers',
#    'following_url': 'https://api.github.com/users/devinsays/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/devinsays/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/devinsays/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/devinsays/subscriptions',
#    'organizations_url': 'https://api.github.com/users/devinsays/orgs',
#    'repos_url': 'https://api.github.com/users/devinsays/repos',
#    'events_url': 'https://api.github.com/users/devinsays/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/devinsays/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/devinsays/woocommerce-customer-source',
#   'description': 'Learn where your WooCommerce customers are coming from.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source',
#   'forks_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/forks',
#   'keys_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/teams',
#   'hooks_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/hooks',
#   'issue_events_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/events',
#   'assignees_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/tags',
#   'blobs_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/languages',
#   'stargazers_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/stargazers',
#   'contributors_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/contributors',
#   'subscribers_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/subscribers',
#   'subscription_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/subscription',
#   'commits_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/merges',
#   'archive_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/downloads',
#   'issues_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/devinsays/woocommerce-customer-source/deployments',
#   'created_at': '2017-12-06T22:44:11Z',
#   'updated_at': '2021-07-09T10:39:10Z',
#   'pushed_at': '2017-12-07T21:17:40Z',
#   'git_url': 'git://github.com/devinsays/woocommerce-customer-source.git',
#   'ssh_url': 'git@github.com:devinsays/woocommerce-customer-source.git',
#   'clone_url': 'https://github.com/devinsays/woocommerce-customer-source.git',
#   'svn_url': 'https://github.com/devinsays/woocommerce-customer-source',
#   'homepage': None,
#   'size': 15,
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'gpl-2.0',
#    'name': 'GNU General Public License v2.0',
#    'spdx_id': 'GPL-2.0',
#    'url': 'https://api.github.com/licenses/gpl-2.0',
#    'node_id': 'MDc6TGljZW5zZTg='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 7,
#   'default_branch': 'master',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0},
#  {'id': 422295993,
#   'node_id': 'R_kgDOGSu5uQ',
#   'name': 'aws-customer-playbook-framework',
#   'full_name': 'aws-samples/aws-customer-playbook-framework',
#   'private': False,
#   'owner': {'login': 'aws-samples',
#    'id': 8931462,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5MzE0NjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8931462?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aws-samples',
#    'html_url': 'https://github.com/aws-samples',
#    'followers_url': 'https://api.github.com/users/aws-samples/followers',
#    'following_url': 'https://api.github.com/users/aws-samples/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/aws-samples/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/aws-samples/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/aws-samples/subscriptions',
#    'organizations_url': 'https://api.github.com/users/aws-samples/orgs',
#    'repos_url': 'https://api.github.com/users/aws-samples/repos',
#    'events_url': 'https://api.github.com/users/aws-samples/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/aws-samples/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/aws-samples/aws-customer-playbook-framework',
#   'description': 'This repository provides sample templates for security playbooks against various scenarios when using Amazon Web Services. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework',
#   'forks_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/forks',
#   'keys_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/teams',
#   'hooks_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/hooks',
#   'issue_events_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/events',
#   'assignees_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/tags',
#   'blobs_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/languages',
#   'stargazers_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/stargazers',
#   'contributors_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/contributors',
#   'subscribers_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/subscribers',
#   'subscription_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/subscription',
#   'commits_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/merges',
#   'archive_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/downloads',
#   'issues_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/aws-samples/aws-customer-playbook-framework/deployments',
#   'created_at': '2021-10-28T17:26:54Z',
#   'updated_at': '2021-11-02T14:32:11Z',
#   'pushed_at': '2021-10-29T15:08:50Z',
#   'git_url': 'git://github.com/aws-samples/aws-customer-playbook-framework.git',
#   'ssh_url': 'git@github.com:aws-samples/aws-customer-playbook-framework.git',
#   'clone_url': 'https://github.com/aws-samples/aws-customer-playbook-framework.git',
#   'svn_url': 'https://github.com/aws-samples/aws-customer-playbook-framework',
#   'homepage': '',
#   'size': 4009,
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': True,
#   'topics': ['aws', 'incident-response', 'playbooks'],
#   'visibility': 'public',
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 7,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True},
#   'score': 1.0}]

# %%
#Convert the reponse to a data frame
urls_df = pd.DataFrame(payload['items'])

# %%
#Check the shape of the dataframe
urls_df.shape
# Out:
# (100, 79)

# %%
urls_df
# Out:
#            id                           node_id  \
# 0   118996371  MDEwOlJlcG9zaXRvcnkxMTg5OTYzNzE=
# 1    58745539  MDEwOlJlcG9zaXRvcnk1ODc0NTUzOQ==
# 2    62332503  MDEwOlJlcG9zaXRvcnk2MjMzMjUwMw==
# 3    85580569  MDEwOlJlcG9zaXRvcnk4NTU4MDU2OQ==
# 4    47967191  MDEwOlJlcG9zaXRvcnk0Nzk2NzE5MQ==
# ..        ...                               ...
# 95  102245898  MDEwOlJlcG9zaXRvcnkxMDIyNDU4OTg=
# 96  181278845  MDEwOlJlcG9zaXRvcnkxODEyNzg4NDU=
# 97  149399792  MDEwOlJlcG9zaXRvcnkxNDkzOTk3OTI=
# 98  113375100  MDEwOlJlcG9zaXRvcnkxMTMzNzUxMDA=
# 99  422295993                      R_kgDOGSu5uQ
#
#                                                  name  \
# 0                                       CustomerChurn
# 1                                  vc-module-customer
# 2                                     customer_portal
# 3                                     customer-portal
# 4                                    customer-scripts
# ..                                                ...
# 95  Clustering-Analysis-on-customers-of-a-wholesal...
# 96   Kaggle_santander-customer-transaction-prediction
# 97  Exploratory-Data-Analysis-Customer-Churn-Predi...
# 98                        woocommerce-customer-source
# 99                    aws-customer-playbook-framework
#
#                                             full_name  private  \
# 0                              smit5490/CustomerChurn    False
# 1                    VirtoCommerce/vc-module-customer    False
# 2                       SonarSoftware/customer_portal    False
# 3                              oroinc/customer-portal    False
# 4                          microsoft/customer-scripts    False
# ..                                                ...      ...
# 95  prakhardogra921/Clustering-Analysis-on-custome...    False
# 96  Rajneesh-Tiwari/Kaggle_santander-customer-tran...    False
# 97  Shubha23/Exploratory-Data-Analysis-Customer-Ch...    False
# 98              devinsays/woocommerce-customer-source    False
# 99        aws-samples/aws-customer-playbook-framework    False
#
#                                                 owner  \
# 0   {'login': 'smit5490', 'id': 13723626, 'node_id...
# 1   {'login': 'VirtoCommerce', 'id': 5762443, 'nod...
# 2   {'login': 'SonarSoftware', 'id': 12124408, 'no...
# 3   {'login': 'oroinc', 'id': 4165718, 'node_id': ...
# 4   {'login': 'microsoft', 'id': 6154722, 'node_id...
# ..                                                ...
# 95  {'login': 'prakhardogra921', 'id': 6964449, 'n...
# 96  {'login': 'Rajneesh-Tiwari', 'id': 16912628, '...
# 97  {'login': 'Shubha23', 'id': 17091320, 'node_id...
# 98  {'login': 'devinsays', 'id': 431879, 'node_id'...
# 99  {'login': 'aws-samples', 'id': 8931462, 'node_...
#
#                                              html_url  \
# 0           https://github.com/smit5490/CustomerChurn
# 1   https://github.com/VirtoCommerce/vc-module-cus...
# 2    https://github.com/SonarSoftware/customer_portal
# 3           https://github.com/oroinc/customer-portal
# 4       https://github.com/microsoft/customer-scripts
# ..                                                ...
# 95  https://github.com/prakhardogra921/Clustering-...
# 96  https://github.com/Rajneesh-Tiwari/Kaggle_sant...
# 97  https://github.com/Shubha23/Exploratory-Data-A...
# 98  https://github.com/devinsays/woocommerce-custo...
# 99  https://github.com/aws-samples/aws-customer-pl...
#
#                                           description   fork  \
# 0                                                None  False
# 1                          Contacts management module  False
# 2                        A customer portal for Sonar.  False
# 3   OroCommerce package with customer portal and n...  False
# 4   Repository of scripts provided frequently to o...  False
# ..                                                ...    ...
# 95  Project in which unsupervised learning techniq...  False
# 96  Code for 118th position in Kaggle santander-cu...  False
# 97  Application of K-means clustering. Prediction ...  False
# 98  Learn where your WooCommerce customers are com...  False
# 99  This repository provides sample templates for ...  False
#
#                                                   url  ... allow_forking  \
# 0   https://api.github.com/repos/smit5490/Customer...  ...          True
# 1   https://api.github.com/repos/VirtoCommerce/vc-...  ...          True
# 2   https://api.github.com/repos/SonarSoftware/cus...  ...          True
# 3   https://api.github.com/repos/oroinc/customer-p...  ...          True
# 4   https://api.github.com/repos/microsoft/custome...  ...          True
# ..                                                ...  ...           ...
# 95  https://api.github.com/repos/prakhardogra921/C...  ...          True
# 96  https://api.github.com/repos/Rajneesh-Tiwari/K...  ...          True
# 97  https://api.github.com/repos/Shubha23/Explorat...  ...          True
# 98  https://api.github.com/repos/devinsays/woocomm...  ...          True
# 99  https://api.github.com/repos/aws-samples/aws-c...  ...          True
#
#    is_template                               topics visibility forks  \
# 0        False                                   []     public     8
# 1        False                                   []     public    21
# 2        False                                   []     public    15
# 3        False                                   []     public    15
# 4        False                                   []     public    13
# ..         ...                                  ...        ...   ...
# 95       False                                   []     public     6
# 96       False                                   []     public     3
# 97       False                                   []     public     3
# 98       False                                   []     public     2
# 99        True  [aws, incident-response, playbooks]     public     2
#
#    open_issues watchers default_branch  \
# 0            4       10         master
# 1           14       10            dev
# 2            1       10         master
# 3            5       10         master
# 4            1       10         master
# ..         ...      ...            ...
# 95           0        7         master
# 96           0        7         master
# 97           0        7         master
# 98           0        7         master
# 99           0        7           main
#
#                                           permissions score
# 0   {'admin': False, 'maintain': False, 'push': Fa...   1.0
# 1   {'admin': False, 'maintain': False, 'push': Fa...   1.0
# 2   {'admin': False, 'maintain': False, 'push': Fa...   1.0
# 3   {'admin': False, 'maintain': False, 'push': Fa...   1.0
# 4   {'admin': False, 'maintain': False, 'push': Fa...   1.0
# ..                                                ...   ...
# 95  {'admin': False, 'maintain': False, 'push': Fa...   1.0
# 96  {'admin': False, 'maintain': False, 'push': Fa...   1.0
# 97  {'admin': False, 'maintain': False, 'push': Fa...   1.0
# 98  {'admin': False, 'maintain': False, 'push': Fa...   1.0
# 99  {'admin': False, 'maintain': False, 'push': Fa...   1.0
#
# [100 rows x 79 columns]

# %%
#Get a list of the full_name for the urls. Saved to acquire seperate file as repos and assigned to a variable
urls_df.full_name.to_list()
# Out:
# ['smit5490/CustomerChurn',
#  'VirtoCommerce/vc-module-customer',
#  'SonarSoftware/customer_portal',
#  'oroinc/customer-portal',
#  'microsoft/customer-scripts',
#  'correooke/example-customers-app',
#  'darkdreamingdan/mlnd-customer-segments',
#  'emilybache/CustomerSync-Refactoring-Kata',
#  'devmentors/Pacco.Services.Customers',
#  'bestkao/customer_segments',
#  'toshi-k/kaggle-santander-customer-satisfaction',
#  'cometchat-pro-tutorials/react-customer-support-live-widget',
#  'celestinhermez/sparkify_customer_churn',
#  'Ifihan/customer-management-app',
#  'skioo/django-customer-billing',
#  'anqi666/Customer-Data-Analysis',
#  'mutedblues/Customer-Success-Management',
#  'ho-nl/magento1-Ho_Customer',
#  'aryashah2k/Datalogy-Customer-Segmentation-Data-Science-Internship',
#  'Horizon733/customer-care-chatbot',
#  'dserradji/reactive-customer-service',
#  'Ashniu123/nestjs-customer-order-eventsourcing-cqrs',
#  'M-R-K-Development/bc-customer-plugin',
#  'melihbodr/Sentiment_analysis_to_customer_comments',
#  'nd009/creating_customer_segments',
#  'digitalcreations/CustomerIOSharp',
#  'fnneves/customer_retention',
#  'Pranov1984/Prediction-of-customer-propensity-to-churn',
#  'magekey/module-customer-restriction',
#  'typesafehub/customers',
#  'aws-samples/build-a-360-degree-customer-view-with-aws',
#  'twilio-professional-services/example-customer-end-chat',
#  'cloudteams/CustomerPlatform',
#  'eventuate-examples/eventuate-micronaut-examples-customers-and-orders',
#  'CasiaFan/customer_lifetime_value_prediction',
#  'linwt/Intelligent-Customer-Service',
#  'wuzixuan1104/customerService',
#  'Wanghongchao12138/CustomerCollectionView',
#  'im3x/weCustomer',
#  'mesudepolat/CUSTOMER_LIFETIME_VALUE',
#  'erenonal/K-means_customer_segmentation',
#  'thomasnield/customer-wait-queue-simulation',
#  'meteorhacks/meteor-customer-io',
#  'latonaio/data-interface-for-salesforce-customer',
#  'apache/fineract-cn-customer',
#  'watson-developer-cloud/customer-engagement-nodejs',
#  'szhua/CustomerServiceAssistant',
#  'deepansh27/CustomerSegmentation',
#  'zhuangjiesen/CustomerAndProvider',
#  'krishnaik06/Predict_customer_Will_Leave_the-Bank',
#  'IBM/run-campaigns-target-customers',
#  'Hari365/customer-segmentation-python',
#  'Rishabh42/Ethereum-customer-loyalty-program',
#  'saikrithik/Janatahack-Customer-Segmentation',
#  'tuyennn/magento2-change-customer-password',
#  'iamar7/Mining-and-Summarising-Customer-Review',
#  'php-cuong/magento2-customer-address-autocomplete',
#  'pranaymodukuru/Bertelsmann-Arvato-customer-segmentation',
#  'dospuntocero/CustomerQuestions',
#  'skyverge/woocommerce-new-customer-report',
#  'customerio/customerio-php',
#  't-varun/Customer-Analytics',
#  'dbashyal/Magento-Customer-Attributes',
#  'Dashride/mongoose-stripe-customers',
#  'Vetrivel-PS/Janatahack-Customer-Segmentation',
#  'ouissa/Customer_Service_Messenger_Bot',
#  'salinaaaaaa/customer-lifetime-value-contractual-or-non-contractual-relationship',
#  'ouyangfeng/CustomerViewGroup',
#  'afaq-ahmad/Gender-and-Age-Detection-based-Customer-Tracking-Classification-on-Raspberry-pi',
#  'bandiang2/Customer-Churn',
#  'mesudepolat/Customer-Lifetime-Value-Prediction',
#  'anchorP34/Starbucks-Customer-Clusters',
#  'aishwarya-pawar/Bank-Customer-Churn-Analysis-',
#  'SooyeonWon/customer_analytics_fmcg',
#  'dwebdevcore/client_portal_customer_FE',
#  'serhatyazicioglu/Customer-Relationship-Management',
#  'shwetapai/Predicting-Customer-Churn-for-a-Telecom-Company',
#  'FOHEART/U3D_Demo_MarketCustomer',
#  'latonaio/data-interface-for-salesforce-customer-bulk-get',
#  'ozzael-codes/CustomerChurnAnalysis',
#  'udacity/MLND_CN_P3_Customer_Segments',
#  'jbossdemocentral/bpms-customer-evaluation-demo',
#  'alfredsasko/Customer-Journey-Analytics',
#  'naseemqota/CustomerOrderSearch',
#  'FaisalAl-Tameemi/ml-customer-segments',
#  'archd3sai/Customer-Survival-Analysis-and-Churn-Prediction',
#  'Arjun-Mota/customer-churn-prediction',
#  'collindching/Olist-customer-churn',
#  'Roc-J/loss_customers',
#  'SohelRaja/Customer-Churn-Analysis',
#  'jalajthanaki/Customer_churn_analysis',
#  'bradtraversy/aurelia_customer_manager',
#  'rakeshmagento/magento2-create-order-for-guest-customer-rest-api',
#  'ankitsingh1240/CUSTOMER-CHURN-PREDICTION',
#  'Nexmo/ruby-sms-customer-engagement',
#  'prakhardogra921/Clustering-Analysis-on-customers-of-a-wholesale-distributor',
#  'Rajneesh-Tiwari/Kaggle_santander-customer-transaction-prediction',
#  'Shubha23/Exploratory-Data-Analysis-Customer-Churn-Prediction',
#  'devinsays/woocommerce-customer-source',
#  'aws-samples/aws-customer-playbook-framework']

# %%
#Use the scrape github function from the acquire module to acquire the dataframe containing the names of the
#repositories and the contents of the readme files
df = acquire.scrape_github_data()

#convert the data into a dataframe
df = pd.DataFrame(df)
df.head()
# Out:
#                                                 repo          language  \
# 0         gongdelu/E-commerce-Customer-service-robot  Jupyter Notebook
# 1                       Azure/fta-customerfacingapps                C#
# 2  ELMAHDI-AR/CustomerAuthentication-With-ASP.NET...        PowerShell
# 3                            kpei/Customer-Analytics  Jupyter Notebook
# 4             Sylius/CustomerOrderCancellationPlugin               PHP
#
#                                      readme_contents
# 0  # E-commerce-Customer-service-robot\n电商多轮对话客服机...
# 1  # FastTrack for Azure\n\nSee our [FastTrack fo...
# 2
# 3  # Customer Analytics iPython Notebook\nSee htt...
# 4  > :warning: **BEWARE!**\n> This repository has...

# %%
# read in the json file generated by compiling the acquire.py file
df = pd.read_json('data2.json')

# %%
df.head()
# Out:
#                                                 repo          language  \
# 0         gongdelu/E-commerce-Customer-service-robot  Jupyter Notebook
# 1                       Azure/fta-customerfacingapps                C#
# 2  ELMAHDI-AR/CustomerAuthentication-With-ASP.NET...        PowerShell
# 3                            kpei/Customer-Analytics  Jupyter Notebook
# 4             Sylius/CustomerOrderCancellationPlugin               PHP
#
#                                      readme_contents
# 0  # E-commerce-Customer-service-robot\n电商多轮对话客服机...
# 1  # FastTrack for Azure\n\nSee our [FastTrack fo...
# 2
# 3  # Customer Analytics iPython Notebook\nSee htt...
# 4  > :warning: **BEWARE!**\n> This repository has...

# %%
len(df)
# Out:
# 200

# %%
# do drop unneeded data first then prep
df = prepare.drop_unneeded_data(df)

# %%
df.head()
# Out:
#                                          repo          language  \
# 0  gongdelu/E-commerce-Customer-service-robot  Jupyter Notebook
# 1                     kpei/Customer-Analytics  Jupyter Notebook
# 2      Sylius/CustomerOrderCancellationPlugin               PHP
# 3          optiflow/rfm-customer-segmentation  Jupyter Notebook
# 4                Sylius/CustomerReorderPlugin               PHP
#
#                                      readme_contents
# 0   EcommerceCustomerservicerobot    SeqSeqGRUGRU...
# 1            Customer Analytics iPython Notebook See
# 2   warning BEWARE  This repository has been depr...
# 3   Recency Frequency and Monetary RFM Customer S...
# 4   warning BEWARE  This repository has been depr...

# %%
df = prepare_nlp_data(df, content = 'readme_contents')

# %%
df.head()
# Out:
#                                          repo          language  \
# 0  gongdelu/E-commerce-Customer-service-robot  Jupyter Notebook
# 1                     kpei/Customer-Analytics  Jupyter Notebook
# 2      Sylius/CustomerOrderCancellationPlugin               PHP
# 3          optiflow/rfm-customer-segmentation  Jupyter Notebook
# 4                Sylius/CustomerReorderPlugin               PHP
#
#                                      readme_contents  \
# 0   EcommerceCustomerservicerobot    SeqSeqGRUGRU...
# 1            Customer Analytics iPython Notebook See
# 2   warning BEWARE  This repository has been depr...
# 3   Recency Frequency and Monetary RFM Customer S...
# 4   warning BEWARE  This repository has been depr...
#
#                                                clean  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1            customer analytics ipython notebook see
# 2  warning beware repository deprecated maintaine...
# 3  recency frequency monetary rfm customer segmen...
# 4  warning beware repository deprecated maintaine...
#
#                                              stemmed  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1                 custom analyt ipython notebook see
# 2  warn bewar repositori deprec maintain evolv sy...
# 3  recenc frequenc monetari rfm custom segment us...
# 4  warn bewar repositori deprec maintain evolv sy...
#
#                                           lemmatized
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1            customer analytics ipython notebook see
# 2  warning beware repository deprecated maintaine...
# 3  recency frequency monetary rfm customer segmen...
# 4  warning beware repository deprecated maintaine...

# %% [markdown]
# ## Explore - What are the most common words in the README?

# %%
words = ' '.join(df.stemmed)

# %%
words[0:1500]
# Out:
# 'ecommercecustomerservicerobot seqseqgrugruteach forc torch jieba numpi custom analyt ipython notebook see warn bewar repositori deprec maintain evolv syliu team still use compat syliu version risk bug fix custom order cancel plugin plugin allow custom cancel place order process screenshot show custom order page cancel buttonsdocsscreenshot png busi valu far custom chang mind alreadi place order administr cancel order howev ask question cant custom cancel order yet paid come custom order cancel plugin allow cancel unpaid order straight order histori view instal bewar instal instruct assum your use symfoni flex dont take look legaci instal instructiondocslegacyinstal md howev strongli encourag use symfoni flex much quicker instal plugin requir compos bash compos requir syliuscustomerordercancellationplugin rememb allow commun recip compos config extra symfoni allowcontrib true plugin instal process extens point custom order cancel plugin use order entiti deriv syliuscorebundl well alreadi defin state default plugin implement assum order cancel custom payment state awaitingpay shipment state equal readi condit easili chang creat custom implement customerordercancellationcheckerinterfac decor exist one secur issu think found secur issu pleas use issu tracker post publicli instead secur issu must sent securitysyliu com recenc frequenc monetari rfm custom segment use kmean articl explain detail approach publish dataset dataset obtain uci machin learn licens content repositori cover'

# %%
frequencies = pd.Series(words.split()).value_counts()

# %%
frequencies.head(50)
# Out:
# custom      923
# data        424
# use         407
# model       258
# creat       209
# instal      169
# project     151
# run         150
# file        150
# featur      147
# new         144
# notebook    136
# account     133
# magento     128
# set         127
# segment     115
# png         110
# valu        107
# churn       106
# code        106
# select      105
# follow      103
# product     103
# predict     102
# click       101
# servic       95
# login        94
# one          93
# market       92
# need         91
# compani      90
# deploy       90
# email        90
# inform       89
# test         89
# requir       89
# page         89
# provid       89
# name         88
# approv       87
# view         86
# time         85
# function     85
# get          82
# also         82
# add          81
# applic       80
# api          80
# configur     79
# learn        79
# dtype: int64

# %%
top_20_words = frequencies.head(20)

# %%
top_20_words.plot.barh()
title = plt.title('Top 20 Most Common Words')

# %%
from wordcloud import WordCloud

# %%
data = {k: v for k, v in top_20_words.to_dict().items()}
img = WordCloud(background_color='white', width=800, height=400).generate_from_frequencies(data)
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Does the length of the README vary by programming language?

# %%
df.head()
# Out:
#                                          repo          language  \
# 0  gongdelu/E-commerce-Customer-service-robot  Jupyter Notebook
# 1                     kpei/Customer-Analytics  Jupyter Notebook
# 2      Sylius/CustomerOrderCancellationPlugin               PHP
# 3          optiflow/rfm-customer-segmentation  Jupyter Notebook
# 4                Sylius/CustomerReorderPlugin               PHP
#
#                                      readme_contents  \
# 0   EcommerceCustomerservicerobot    SeqSeqGRUGRU...
# 1            Customer Analytics iPython Notebook See
# 2   warning BEWARE  This repository has been depr...
# 3   Recency Frequency and Monetary RFM Customer S...
# 4   warning BEWARE  This repository has been depr...
#
#                                                clean  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1            customer analytics ipython notebook see
# 2  warning beware repository deprecated maintaine...
# 3  recency frequency monetary rfm customer segmen...
# 4  warning beware repository deprecated maintaine...
#
#                                              stemmed  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1                 custom analyt ipython notebook see
# 2  warn bewar repositori deprec maintain evolv sy...
# 3  recenc frequenc monetari rfm custom segment us...
# 4  warn bewar repositori deprec maintain evolv sy...
#
#                                           lemmatized
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1            customer analytics ipython notebook see
# 2  warning beware repository deprecated maintaine...
# 3  recency frequency monetary rfm customer segmen...
# 4  warning beware repository deprecated maintaine...

# %%
length_readme = []
for i in range(len(df)):
    length_readme.append(len(df.readme_contents[i]))

# %%
length_readme_df = pd.DataFrame(length_readme)

# %%
df = pd.concat([df, length_readme_df], axis = 1)

# %%
df.head()
# Out:
#                                          repo          language  \
# 0  gongdelu/E-commerce-Customer-service-robot  Jupyter Notebook
# 1                     kpei/Customer-Analytics  Jupyter Notebook
# 2      Sylius/CustomerOrderCancellationPlugin               PHP
# 3          optiflow/rfm-customer-segmentation  Jupyter Notebook
# 4                Sylius/CustomerReorderPlugin               PHP
#
#                                      readme_contents  \
# 0   EcommerceCustomerservicerobot    SeqSeqGRUGRU...
# 1            Customer Analytics iPython Notebook See
# 2   warning BEWARE  This repository has been depr...
# 3   Recency Frequency and Monetary RFM Customer S...
# 4   warning BEWARE  This repository has been depr...
#
#                                                clean  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1            customer analytics ipython notebook see
# 2  warning beware repository deprecated maintaine...
# 3  recency frequency monetary rfm customer segmen...
# 4  warning beware repository deprecated maintaine...
#
#                                              stemmed  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1                 custom analyt ipython notebook see
# 2  warn bewar repositori deprec maintain evolv sy...
# 3  recenc frequenc monetari rfm custom segment us...
# 4  warn bewar repositori deprec maintain evolv sy...
#
#                                           lemmatized     0
# 0  ecommercecustomerservicerobot seqseqgrugruteac...    83
# 1            customer analytics ipython notebook see    40
# 2  warning beware repository deprecated maintaine...  1901
# 3  recency frequency monetary rfm customer segmen...   255
# 4  warning beware repository deprecated maintaine...  2764

# %%
df.rename(columns = {0: "length"}, inplace = True)

# %%
df.head()
# Out:
#                                          repo          language  \
# 0  gongdelu/E-commerce-Customer-service-robot  Jupyter Notebook
# 1                     kpei/Customer-Analytics  Jupyter Notebook
# 2      Sylius/CustomerOrderCancellationPlugin               PHP
# 3          optiflow/rfm-customer-segmentation  Jupyter Notebook
# 4                Sylius/CustomerReorderPlugin               PHP
#
#                                      readme_contents  \
# 0   EcommerceCustomerservicerobot    SeqSeqGRUGRU...
# 1            Customer Analytics iPython Notebook See
# 2   warning BEWARE  This repository has been depr...
# 3   Recency Frequency and Monetary RFM Customer S...
# 4   warning BEWARE  This repository has been depr...
#
#                                                clean  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1            customer analytics ipython notebook see
# 2  warning beware repository deprecated maintaine...
# 3  recency frequency monetary rfm customer segmen...
# 4  warning beware repository deprecated maintaine...
#
#                                              stemmed  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1                 custom analyt ipython notebook see
# 2  warn bewar repositori deprec maintain evolv sy...
# 3  recenc frequenc monetari rfm custom segment us...
# 4  warn bewar repositori deprec maintain evolv sy...
#
#                                           lemmatized  length
# 0  ecommercecustomerservicerobot seqseqgrugruteac...      83
# 1            customer analytics ipython notebook see      40
# 2  warning beware repository deprecated maintaine...    1901
# 3  recency frequency monetary rfm customer segmen...     255
# 4  warning beware repository deprecated maintaine...    2764

# %%
df.language.value_counts()
# Out:
# Jupyter Notebook    49
# PHP                 38
# Python              25
# JavaScript          24
# Name: language, dtype: int64

# %%
jupyter = df[df.language == "Jupyter Notebook"]
php = df[df.language == "PHP"]
python = df[df.language == "Python"]
java = df[df.language == "JavaScript"]

# %%
php.head()
# Out:
#                                        repo language  \
# 2    Sylius/CustomerOrderCancellationPlugin      PHP
# 4              Sylius/CustomerReorderPlugin      PHP
# 7        php-cuong/magento2-customer-avatar      PHP
# 8                         printu/customerio      PHP
# 10  kiwicommerce/magento2-login-as-customer      PHP
#
#                                       readme_contents  \
# 2    warning BEWARE  This repository has been depr...
# 4    warning BEWARE  This repository has been depr...
# 7    Magento  Customer Avatar This is an awesome m...
# 8    Customer io API Client PHP bindings for the C...
# 10   Were not maintaining this extension if you ne...
#
#                                                 clean  \
# 2   warning beware repository deprecated maintaine...
# 4   warning beware repository deprecated maintaine...
# 7   magento customer avatar awesome module allows ...
# 8   customer io api client php bindings customer i...
# 10  maintaining extension need support please cont...
#
#                                               stemmed  \
# 2   warn bewar repositori deprec maintain evolv sy...
# 4   warn bewar repositori deprec maintain evolv sy...
# 7   magento custom avatar awesom modul allow custo...
# 8   custom io api client php bind custom io api ap...
# 10  maintain extens need support pleas contact us ...
#
#                                            lemmatized  length
# 2   warning beware repository deprecated maintaine...    1901
# 4   warning beware repository deprecated maintaine...    2764
# 7   magento customer avatar awesome module allows ...    1247
# 8   customer io api client php binding customer io...    2883
# 10  maintaining extension need support please cont...    2748

# %%
jupyter = jupyter.reset_index()
php = php.reset_index()
python = python.reset_index()
java = java.reset_index()

# %%
dataframes = [jupyter, php, python, java]
for lang in dataframes:
    print(lang.language[0])
    print("Median READme length", lang.length.median())
    print("Mean READme length", lang.length.mean())
    print(" ")
# Out:
# Jupyter Notebook
# Median READme length 1644.0
# Mean READme length 3242.938775510204
#
# PHP
# Median READme length 746.5
# Mean READme length 1439.4736842105262
#
# Python
# Median READme length 644.0
# Mean READme length 1579.96
#
# JavaScript
# Median READme length 1107.5
# Mean READme length 2354.375

# %%
not_jupyter = [php, python, java]
for lang in not_jupyter:
    print(lang.language[0], "average READme length vs Jupyter average length")
    print(stats.ttest_ind(lang.length, jupyter.length))
    print(" ")
# Out:
# PHP average READme length vs Jupyter average length
# Ttest_indResult(statistic=-1.8616184902205477, pvalue=0.06611305850967955)
#
# Python average READme length vs Jupyter average length
# Ttest_indResult(statistic=-1.3835831902700682, pvalue=0.17076087452026897)
#
# JavaScript average READme length vs Jupyter average length
# Ttest_indResult(statistic=-0.7091768908777644, pvalue=0.4805370466090102)

# %%
not_php = [python, java]
for lang in not_php:
    print(lang.language[0], "average READme length vs PHP average length")
    print(stats.ttest_ind(lang.length, php.length))
    print(" ")
# Out:
# Python average READme length vs PHP average length
# Ttest_indResult(statistic=0.22927542200610088, pvalue=0.8194218622696456)
#
# JavaScript average READme length vs PHP average length
# Ttest_indResult(statistic=1.3276887891704021, pvalue=0.18931025885020386)

# %%
for lang in dataframes:
    print(lang.language[0], "READme length vs all languages READme lengths")
    print(stats.ttest_1samp(lang.length, df.length.mean()))
    print(" ")
# Out:
# Jupyter Notebook READme length vs all languages READme lengths
# Ttest_1sampResult(statistic=1.193575271661778, pvalue=0.23851004226093867)
#
# PHP READme length vs all languages READme lengths
# Ttest_1sampResult(statistic=-2.4404955964402517, pvalue=0.019575195371731947)
#
# Python READme length vs all languages READme lengths
# Ttest_1sampResult(statistic=-1.271917776615204, pvalue=0.21558940036119228)
#
# JavaScript READme length vs all languages READme lengths
# Ttest_1sampResult(statistic=0.11482863002003657, pvalue=0.9095775400216792)

# %% [markdown]
# ## Do different programming languages use a different number of unique words?

# %%
jupyter_words = ' '.join(jupyter.stemmed)

# %%
jupyter_unique_words = len(set(re.findall('\w+', jupyter_words)))

# %%
jupyter_unique_words
# Out:
# 2630

# %%
php_words = ' '.join(php.stemmed)

# %%
php_unique_words = len(set(re.findall('\w+', php_words)))

# %%
php_unique_words
# Out:
# 1106

# %%
python_words = ' '.join(python.stemmed)

# %%
python_unique_words = len(set(re.findall('\w+', python_words)))

# %%
python_unique_words
# Out:
# 1291

# %%
java_words = ' '.join(java.stemmed)

# %%
java_unique_words = len(set(re.findall('\w+', java_words)))

# %%
java_unique_words
# Out:
# 1395

# %%
all_words_unique = []
for i in range(len(df)):
    all_words_unique.append(len(set(re.findall('\w+', df.stemmed[i]))))

# %%
words_unique_df = pd.DataFrame(all_words_unique)

# %%
df = pd.concat([df, words_unique_df], axis = 1)
df.head()
# Out:
#                                          repo          language  \
# 0  gongdelu/E-commerce-Customer-service-robot  Jupyter Notebook
# 1                     kpei/Customer-Analytics  Jupyter Notebook
# 2      Sylius/CustomerOrderCancellationPlugin               PHP
# 3          optiflow/rfm-customer-segmentation  Jupyter Notebook
# 4                Sylius/CustomerReorderPlugin               PHP
#
#                                      readme_contents  \
# 0   EcommerceCustomerservicerobot    SeqSeqGRUGRU...
# 1            Customer Analytics iPython Notebook See
# 2   warning BEWARE  This repository has been depr...
# 3   Recency Frequency and Monetary RFM Customer S...
# 4   warning BEWARE  This repository has been depr...
#
#                                                clean  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1            customer analytics ipython notebook see
# 2  warning beware repository deprecated maintaine...
# 3  recency frequency monetary rfm customer segmen...
# 4  warning beware repository deprecated maintaine...
#
#                                              stemmed  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1                 custom analyt ipython notebook see
# 2  warn bewar repositori deprec maintain evolv sy...
# 3  recenc frequenc monetari rfm custom segment us...
# 4  warn bewar repositori deprec maintain evolv sy...
#
#                                           lemmatized  length    0
# 0  ecommercecustomerservicerobot seqseqgrugruteac...      83    6
# 1            customer analytics ipython notebook see      40    5
# 2  warning beware repository deprecated maintaine...    1901  107
# 3  recency frequency monetary rfm customer segmen...     255   23
# 4  warning beware repository deprecated maintaine...    2764  143

# %%
df.rename(columns = {0: "unique_words"}, inplace = True)

# %%
jupyter = df[df.language == "Jupyter Notebook"]
php = df[df.language == "PHP"]
python = df[df.language == "Python"]
java = df[df.language == "JavaScript"]

# %%
jupyter = jupyter.reset_index()
php = php.reset_index()
python = python.reset_index()
java = java.reset_index()

# %%
not_jupyter = [php, python, java]
for lang in not_jupyter:
    print(lang.language[0], "average unique words vs Jupyter average unique words")
    print(stats.ttest_ind(lang.unique_words, jupyter.unique_words))
    print(" ")
# Out:
# PHP average unique words vs Jupyter average unique words
# Ttest_indResult(statistic=-2.433140313673896, pvalue=0.017064510499042333)
#
# Python average unique words vs Jupyter average unique words
# Ttest_indResult(statistic=-1.6128187626187684, pvalue=0.11115882462933681)
#
# JavaScript average unique words vs Jupyter average unique words
# Ttest_indResult(statistic=-0.7889065178819505, pvalue=0.43279310141216065)

# %%
not_php = [python, java]
for lang in not_php:
    print(lang.language[0], "average unique words vs PHP average unique words")
    print(stats.ttest_ind(lang.unique_words, php.unique_words))
    print(" ")
# Out:
# Python average unique words vs PHP average unique words
# Ttest_indResult(statistic=0.4580777078010558, pvalue=0.6485243059897029)
#
# JavaScript average unique words vs PHP average unique words
# Ttest_indResult(statistic=1.8137204264009048, pvalue=0.07472229430094941)

# %%
print("Python average unique words vs Java average unique words")
print(stats.ttest_ind(python.unique_words, java.unique_words))
# Out:
# Python average unique words vs Java average unique words
# Ttest_indResult(statistic=-0.9490050476017465, pvalue=0.34747246057657355)

# %% [markdown]
# ###
# - Javascript unique words differs significantly from PHP.
# - Jupyter Notebook differs significantly from PHP.

# %%
df.head()
# Out:
#                                          repo          language  \
# 0  gongdelu/E-commerce-Customer-service-robot  Jupyter Notebook
# 1                     kpei/Customer-Analytics  Jupyter Notebook
# 2      Sylius/CustomerOrderCancellationPlugin               PHP
# 3          optiflow/rfm-customer-segmentation  Jupyter Notebook
# 4                Sylius/CustomerReorderPlugin               PHP
#
#                                      readme_contents  \
# 0   EcommerceCustomerservicerobot    SeqSeqGRUGRU...
# 1            Customer Analytics iPython Notebook See
# 2   warning BEWARE  This repository has been depr...
# 3   Recency Frequency and Monetary RFM Customer S...
# 4   warning BEWARE  This repository has been depr...
#
#                                                clean  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1            customer analytics ipython notebook see
# 2  warning beware repository deprecated maintaine...
# 3  recency frequency monetary rfm customer segmen...
# 4  warning beware repository deprecated maintaine...
#
#                                              stemmed  \
# 0  ecommercecustomerservicerobot seqseqgrugruteac...
# 1                 custom analyt ipython notebook see
# 2  warn bewar repositori deprec maintain evolv sy...
# 3  recenc frequenc monetari rfm custom segment us...
# 4  warn bewar repositori deprec maintain evolv sy...
#
#                                           lemmatized  length  unique_words
# 0  ecommercecustomerservicerobot seqseqgrugruteac...      83             6
# 1            customer analytics ipython notebook see      40             5
# 2  warning beware repository deprecated maintaine...    1901           107
# 3  recency frequency monetary rfm customer segmen...     255            23
# 4  warning beware repository deprecated maintaine...    2764           143

# %%
dataframes = [jupyter, php, python, java]

# %%
for lang in dataframes:
    print(lang.language[0], "unique words vs all languages unique words")
    print(stats.ttest_1samp(lang.unique_words, df.unique_words.mean()))
    print(" ")
# Out:
# Jupyter Notebook unique words vs all languages unique words
# Ttest_1sampResult(statistic=1.4898071344052946, pvalue=0.14281701172334046)
#
# PHP unique words vs all languages unique words
# Ttest_1sampResult(statistic=-3.4211473401817645, pvalue=0.0015350607370688137)
#
# Python unique words vs all languages unique words
# Ttest_1sampResult(statistic=-1.1020450367274606, pvalue=0.28137148824009134)
#
# JavaScript unique words vs all languages unique words
# Ttest_1sampResult(statistic=0.25732548982471065, pvalue=0.799215716548088)

# %% [markdown]
# ## Only PHP has significantly different unique word from the population.
#
# *************************
#
# ## Time to Split the data

# %%
train, validate, test = prepare.split_data(df)
# Out:
# train---> (75, 8)
# validate---> (33, 8)
# test---> (28, 8)

# %%
all_word_counts = explore.get_word_counts_series(train, 'lemmatized')
java_word_counts = explore.get_word_counts_series(train[train.language == 'Java'], 'lemmatized')
javascript_word_counts = explore.get_word_counts_series(train[train.language == 'JavaScript'], 'lemmatized')
php_word_counts = explore.get_word_counts_series(train[train.language == 'PHP'], 'lemmatized')
jupyter_word_counts = explore.get_word_counts_series(train[train.language == 'Jupyter Notebook'], 'lemmatized')

# %%
all_word_counts[all_word_counts.index == 'customer']
# Out:
# customer    476
# dtype: int64

# %%
word_counts_list = [java_word_counts, javascript_word_counts, php_word_counts, jupyter_word_counts, all_word_counts]
column_names = list(df.language.unique())
column_names.append('all')

languages = list(df.language.unique())

# %%
word_counts = pd.concat(word_counts_list, axis=1).fillna(0).astype(int)
word_counts.columns = column_names
word_counts.head()
# Out:
#            Jupyter Notebook  PHP  Python  JavaScript  all
# aa                        0    0       0           2    2
# abandoned                 0    0       1           0    1
# ability                   0    0       1           1    2
# able                      0    0       3           7   10
# abrir                     0    0       0           0    2

# %%
def plot_overlap_stacked_bar(word_counts, category, num_top = 20, cmap = None):
    '''
    This function takes in word_counts df
        - Must have counts for each category as well as a category named 'all'
    category you want to sort by (aka top 20 words in java readmes)
    num_top is how many words you want to see the proportion of, default = 20
    Default colors are tab10 but you can customize that
    
    for cmap use 'viridis'
    
    '''
    plt.figure(figsize=(16, 9))
    plt.rc('font', size=16)
    # axis=1 in .apply means row by row
    (word_counts.sort_values(by='all', ascending=False)
     .head(num_top)
     .apply(lambda row: row / row['all'], axis=1)
     .drop(columns='all')
     .sort_values(by=category)
     .plot.barh(stacked=True, width=1, ec='lightgrey', cmap = cmap, alpha = 1))
    plt.legend(bbox_to_anchor= (1.03,1))
    plt.title(f'% of most common {num_top} {category} Readme Words\n')
    plt.xlabel('\nProportion of Overlap')
    # make tick lables display as percentages!! 
    plt.gca().xaxis.set_major_formatter(mpl.ticker.FuncFormatter('{:.0%}'.format))
    
    plt.show()

# %%
for language in languages:
    plot_overlap_stacked_bar(word_counts, language, cmap = 'viridis')

# %% [markdown]
# ### Take aways
#
# - magento and model were among the top 20 in each language

# %%
df.language.value_counts()
# Out:
# Jupyter Notebook    49
# PHP                 38
# Python              25
# JavaScript          24
# Name: language, dtype: int64

# %%
#PHP is the baseline prediction
print(f'Baseline Accuracy: {round(max(train.language.value_counts()) / train.shape[0] *100)}%')
# Out:
# Baseline Accuracy: 36%

# %% [markdown]
# ## Lemmatized

# %%
# create dataframe to store the scores
score_df = pd.DataFrame(columns = ['model_name', 'train_score', 'validate_score'])

# %%
#TD/IDF vectorizer on the lemmatized data.

# %%
tfidf = TfidfVectorizer()
X_data = tfidf.fit_transform(df.lemmatized)
y_data = df.language

# split to X/y datasets 
X_train, y_train, X_validate, y_validate, X_test, y_test = m.nlp_X_train_split(X_data, y_data)

# %%
# create list of models to loop through
model_list = [MultinomialNB(), LinearSVC(), DecisionTreeClassifier(), RandomForestClassifier(), KNeighborsClassifier(), LogisticRegression()]

# create list of model names that correspond to models
model_names = ['Naive_Bayes_tfidf_lemmatized', 'SVC_tfidf_lemmatized', 'Decision_tree_tfidf_lemmatized', 
               'Random_forest_tfidf_lemmatized', 'KNN_tfidf_lemmatized', 'Log_reg_tfidf_lemmatized']

# initialize list of names of the languages
class_names = ['Java', 'JavaScript', 'Python','PHP' ]

# %%
for model, name in zip(model_list, model_names):
    score_df = m.test_a_model(X_train, y_train, X_validate, y_validate, model, name, score_df)

# %%
#stemmed data still using the TD/IDF vectorizer.

# %%
# bring in the vectorizer
tfidf = TfidfVectorizer()

X_data = tfidf.fit_transform(df.stemmed)
y_data = df.language

# split to X/y datasets 
X_train, y_train, X_validate, y_validate, X_test, y_test = m.nlp_X_train_split(X_data, y_data)

# %%
# make a list of algorithms we want to try for our models
model_list = [MultinomialNB(), LinearSVC(), DecisionTreeClassifier(), RandomForestClassifier(), KNeighborsClassifier(), LogisticRegression()]

# name the models
model_names = ['Naive_Bayes_stemmed', 'SVC_stemmed', 'Decision_tree_stemmed', 'Random_forest_stemmed', 'KNN_bigrams_stemmed', 'Log_reg_stemmed']

# list the languages
class_names = ['Java', 'JavaScript', 'Python','PHP' ]

# %%
for model, name in zip(model_list, model_names):
    score_df = m.test_a_model(X_train, y_train, X_validate, y_validate, model, name, score_df)

# %%
score_df
# Out:
#                         model_name  train_score  validate_score
# 0     Naive_Bayes_tfidf_lemmatized     0.880000        0.575758
# 1             SVC_tfidf_lemmatized     0.973333        0.787879
# 2   Decision_tree_tfidf_lemmatized     0.973333        0.727273
# 3   Random_forest_tfidf_lemmatized     0.973333        0.878788
# 4             KNN_tfidf_lemmatized     0.933333        0.727273
# 5         Log_reg_tfidf_lemmatized     0.946667        0.606061
# 6              Naive_Bayes_stemmed     0.826667        0.575758
# 7                      SVC_stemmed     0.973333        0.757576
# 8            Decision_tree_stemmed     0.973333        0.727273
# 9            Random_forest_stemmed     0.973333        0.818182
# 10             KNN_bigrams_stemmed     0.906667        0.666667
# 11                 Log_reg_stemmed     0.946667        0.636364

# %% [markdown]
# Takeaways
#
# - Overall most of the models performed well
# - It looks like most of the models utilizing the stemmed data are overfit
# - Using the stemmed data does not give us better accuracy than the lemmatized data
#
# Let's see how our models do with bigrams using lemmatized data.

# %%
tfidf = TfidfVectorizer(ngram_range=(2,2))
X_data = tfidf.fit_transform(df.lemmatized)
y_data = df.language

X_train, y_train, X_validate, y_validate, X_test, y_test = m.nlp_X_train_split(X_data, y_data)

# %%
model_list = [MultinomialNB(), LinearSVC(), DecisionTreeClassifier(), RandomForestClassifier(), KNeighborsClassifier()]

model_names = ['Naive_Bayes_tfidf2', 'SVC_tfidf2', 'Decision_tree_tfidf2', 'Random_forest_tfidf2', 'KNN_bigrams_tfidf2']

class_names = ['Java', 'JavaScript', 'Python','PHP' ]

# %%
for model, name in zip(model_list, model_names):
    score_df = m.test_a_model(X_train, y_train, X_validate, y_validate, model, name, score_df)

# %%
#using just the clean data (not lemmatized or stemmed)

# %%
tfidf = TfidfVectorizer()
X_data = tfidf.fit_transform(df.clean)
y_data = df.language

X_train, y_train, X_validate, y_validate, X_test, y_test = m.nlp_X_train_split(X_data, y_data)

# %%
model_list = [MultinomialNB(), LinearSVC(), DecisionTreeClassifier(), RandomForestClassifier(), KNeighborsClassifier(n_neighbors=10, weights= 'distance'),
             LogisticRegression()]

model_names = ['Naive_Bayes_tfidf_clean', 'SVC_tfidf_clean', 'Decision_tree_tfidf_clean', 'Random_forest_tfidf_clean', 'KNN_n10_tfidf_clean',
              'Log_reg_clean']

class_names = ['Java', 'JavaScript', 'Python','PHP' ]

# %%
for model, name in zip(model_list, model_names):
    score_df = m.test_a_model(X_train, y_train, X_validate, y_validate, model, name, score_df)

# %%
score_df.sort_values(by = 'validate_score', ascending = False)
# Out:
#                         model_name  train_score  validate_score
# 3   Random_forest_tfidf_lemmatized     0.973333        0.878788
# 21             KNN_n10_tfidf_clean     0.973333        0.818182
# 20       Random_forest_tfidf_clean     0.973333        0.818182
# 9            Random_forest_stemmed     0.973333        0.818182
# 1             SVC_tfidf_lemmatized     0.973333        0.787879
# 18                 SVC_tfidf_clean     0.973333        0.787879
# 7                      SVC_stemmed     0.973333        0.757576
# 2   Decision_tree_tfidf_lemmatized     0.973333        0.727273
# 4             KNN_tfidf_lemmatized     0.933333        0.727273
# 8            Decision_tree_stemmed     0.973333        0.727273
# 19       Decision_tree_tfidf_clean     0.973333        0.727273
# 10             KNN_bigrams_stemmed     0.906667        0.666667
# 11                 Log_reg_stemmed     0.946667        0.636364
# 14            Decision_tree_tfidf2     0.973333        0.636364
# 22                   Log_reg_clean     0.946667        0.636364
# 5         Log_reg_tfidf_lemmatized     0.946667        0.606061
# 17         Naive_Bayes_tfidf_clean     0.880000        0.575758
# 6              Naive_Bayes_stemmed     0.826667        0.575758
# 0     Naive_Bayes_tfidf_lemmatized     0.880000        0.575758
# 13                      SVC_tfidf2     0.933333        0.545455
# 12              Naive_Bayes_tfidf2     0.920000        0.454545
# 15            Random_forest_tfidf2     0.973333        0.333333
# 16              KNN_bigrams_tfidf2     0.360000        0.181818

# %% [markdown]
# The top score is the KNN_n10_tfidf_clean utilizing the TD/IDf method. Let's take a deeper look at the results from that model with the Train and Validate datasets.

# %%
tfidf = TfidfVectorizer()
X_data = tfidf.fit_transform(df.clean)
y_data = df.language

X_train, y_train, X_validate, y_validate, X_test, y_test = m.nlp_X_train_split(X_data, y_data)

m.make_models_and_print_metrics(KNeighborsClassifier(n_neighbors=10, weights= 'distance'), 'KNN', X_train, y_train, X_validate, y_validate, class_names)
# Out:
#                    ============== KNN ================
# KNeighborsClassifier(n_neighbors=10, weights='distance')
# ~~~~~~~~Train Scores~~~~~~~~~
#                   precision    recall  f1-score   support
#
#       JavaScript       0.87      1.00      0.93        13
# Jupyter Notebook       1.00      1.00      1.00        27
#              PHP       1.00      0.95      0.98        21
#           Python       1.00      0.93      0.96        14
#
#         accuracy                           0.97        75
#        macro avg       0.97      0.97      0.97        75
#     weighted avg       0.98      0.97      0.97        75
# KNeighborsClassifier(n_neighbors=10, weights='distance')
# ~~~~~~~~Validate Scores~~~~~~~~~
#                   precision    recall  f1-score   support
#
#       JavaScript       0.67      0.67      0.67         6
# Jupyter Notebook       0.71      1.00      0.83        12
#              PHP       1.00      0.89      0.94         9
#           Python       1.00      0.33      0.50         6
#
#         accuracy                           0.79        33
#        macro avg       0.84      0.72      0.73        33
#     weighted avg       0.83      0.79      0.77        33
# -------------------------------------------------------------------

# %% [markdown]
# ### Takeaways
#
# While the model is overfit on the training data, it seems to still do well on the Validate set (77% accuracy). It might be due to the amount of readmes we are pulling from. We can take this model now to our test data to see how it performs.

# %%
tfidf = TfidfVectorizer()
X_data = tfidf.fit_transform(df.clean)
y_data = df.language

X_train, y_train, X_validate, y_validate, X_test, y_test = m.nlp_X_train_split(X_data, y_data)

# %%
# The second confusion matrix should be test

m.make_models_and_print_metrics_test_data(KNeighborsClassifier(n_neighbors=10, weights= 'distance'), 'KNN_n10_tfidf_clean', X_train, y_train, X_test, y_test, class_names)
# Out:
#                    ============== KNN_n10_tfidf_clean ================
# KNeighborsClassifier(n_neighbors=10, weights='distance')
# ~~~~~~~~Test Scores~~~~~~~~~
#                   precision    recall  f1-score   support
#
#       JavaScript       0.50      0.40      0.44         5
# Jupyter Notebook       0.77      1.00      0.87        10
#              PHP       0.73      1.00      0.84         8
#           Python       0.00      0.00      0.00         5
#
#         accuracy                           0.71        28
#        macro avg       0.50      0.60      0.54        28
#     weighted avg       0.57      0.71      0.63        28
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# -------------------------------------------------------------------

# %%
# set palette
sns.set_palette('viridis_r')

# set up second dataframe for scores top 7 
score_df2 = score_df.set_index('model_name').sort_values(by = ['validate_score', 'model_name'], ascending = False).head(7)

# add the test score to the model we tested on (KNN)
score_df2['test_score']= [0.64, 0, 0, 0, 0, 0, 0]

# %%
score_df2.sort_values(by= ['test_score', 'validate_score']).plot.barh(alpha = .9, width = 1, ec = 'white', 
                                                                      figsize = (12,6))
# plot baseline
plt.axvline(x = .39, c = 'violet', linestyle = '--')
plt.legend(['Baseline','Train', 'Validate','Test'], bbox_to_anchor = (1.03,1))
plt.ylabel('Model Name')
plt.xlabel('\nAccuracy Score')
# set ticks to percentages
plt.gca().xaxis.set_major_formatter(mpl.ticker.FuncFormatter('{:.0%}'.format))
plt.title('Top 7 Models, Accuracy Score Comparison\n', fontsize = 24)
plt.show()
